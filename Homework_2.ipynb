# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./DATA/Employees.csv')

# %%
df
# Out:
#      Gender  Experience  Salary
# 0    Female          15   78200
# 1    Female          12   66400
# 2    Female          15   61200
# 3    Female           3   61000
# 4    Female           4   60000
# ..      ...         ...     ...
# 203    Male          39  148000
# 204    Male          34  190000
# 205    Male          36  194000
# 206    Male          32  176000
# 207    Male          35  188000
#
# [208 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      208 non-null    object
#  1   Experience  208 non-null    int64
#  2   Salary      208 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 5.0+ KB

# %%
df
# Out:
#      Gender  Experience  Salary
# 0    Female          15   78200
# 1    Female          12   66400
# 2    Female          15   61200
# 3    Female           3   61000
# 4    Female           4   60000
# ..      ...         ...     ...
# 203    Male          39  148000
# 204    Male          34  190000
# 205    Male          36  194000
# 206    Male          32  176000
# 207    Male          35  188000
#
# [208 rows x 3 columns]

# %%
sns.boxplot(x=df['Experience'])
plt.xlim(29)
# Out:
# (29.0, 40.85)

# %%
def func_1(n):
    if n > 28:
        return df['Experience'].median()
    else:
        return n

# %%
df['Experience'] = df['Experience'].apply(func_1)

# %%
sns.boxplot(x = df['Experience'])
# Out:
# <AxesSubplot:xlabel='Experience'>

# %%
sns.boxplot(x = df['Salary'])
plt.xlim(120000)
# Out:
# (120000.0, 201030.0)

# %%
def func_2(n):
    if n > 120001:
        return df['Salary'].median()
    else:
        return n

# %%
df['Salary'] = df['Salary'].apply(func_2)

# %%
sns.boxplot(x = df['Salary'])
plt.xlim(110000)
# Out:
# (110000.0, 123330.0)

# %%
def func_3(n):
    if n > 116000:
        return df['Salary'].median()
    else:
        return n

# %%
df['Salary'] = df['Salary'].apply(func_3)

# %%
sns.boxplot(x = df['Salary'])
plt.xlim(110000)
# Out:
# (110000.0, 119130.0)

# %%
def  func_4(n):
    if n > 113000:
        return df['Salary'].median()
    else:
        return n

# %%
df['Salary'] = df['Salary'].apply(func_4)

# %%
sns.boxplot(x = df['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.boxplot(x = 'Experience',hue = 'Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Experience'>

# %%
plt.figure(figsize=(14,8),dpi=500)
plt.scatter(df['Experience'],df['Salary'])

# %%
len(df[df['Gender']=='Male'])
# Out:
# 68

# %%
def gender_to_numeric(x):
    if x=='Female': return 1
    if x=='Male':   return 0

# %%
df['Gender'] = df['Gender'].apply(gender_to_numeric)

# %%
df
# Out:
#      Gender  Experience   Salary
# 0         1        15.0  78200.0
# 1         1        12.0  66400.0
# 2         1        15.0  61200.0
# 3         1         3.0  61000.0
# 4         1         4.0  60000.0
# ..      ...         ...      ...
# 203       0        10.0  74000.0
# 204       0        10.0  74000.0
# 205       0        10.0  74000.0
# 206       0        10.0  74000.0
# 207       0        10.0  74000.0
#
# [208 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      208 non-null    int64
#  1   Experience  208 non-null    float64
#  2   Salary      208 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 5.0 KB

# %%
sns.boxplot(x=df['Experience'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Experience'>

# %%
sns.boxplot(x=df['Salary'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
X = df.drop('Gender',axis=1)

# %%
y = df['Gender']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error ,r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.21743380213536892

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.0432430591183155

# %%
plt.scatter(df['Salary'],df['Experience'])

# %%
plt.scatter(df['Gender'],df['Salary'])

# %%
plt.scatter(df['Gender'],df['Experience'])

# %%
plt.scatter(df['Gender'],df['Salary'])
